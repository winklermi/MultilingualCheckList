# %%
# Paper: Beyond Accuracy: Behavioral Testing of NLP Models with CheckList ACL 2020

# One sentence summary:
# Method to test the behaviour of NLP models through different experiments on small
# manufactured example test sets.

# Criticism:
# The authors focus mainly on English NLP models and show that the CheckList analyses
# uncover errors in commercial and openly available models. However, there is a wide usage
# of multilingual models in the NLP community for multilingual or low-resource experiments
# which makes an error analysis of multilingual models relevant and interesting.

# Planned Implementation:
# The plan is to take a multilingual model (e.g., mBERT) and create a Minimum Functionality
# Test (MFT) for testing how the model handles negations in parallel Sentiment Analysis
# sentences in English (like "It was bad.", "It was good.", "It was not good."), German ("Es war
# schlecht.", "Es war gut.", "Es war nicht gut.") and Bavarian ("Des war schlecht.", "Des war
# guad.", "Des war ned guad."). The experiments should then show whether the CheckList
# methods can also be used in a multilingual setup and whether mBERT's behaviour changes
# for different languages.

# Feedback:
# The proposal extends CheckList to other languages and implements a Minimum Functionality Test comparing English, German and Bavarian.
# Looks good. Approved.

# %%
# research questions:
# can CheckList be applied to multilingual models? (only tested on English models)
# can CheckList be used to compare model capabilities across languages? (here: has the model different behaviour when handling negations in different languages)
# does CheckList only work for encoder-based models or also for decoder-based models like llama?

# %%
# sources

# code for data creation partly taken from 
# https://github.com/marcotcr/checklist/blob/master/notebooks/tutorials/1.%20Generating%20data.ipynb
# with major changes

# code for test creation and execution partly taken from
# https://github.com/marcotcr/checklist/blob/master/notebooks/tutorials/3.%20Test%20types%2C%20expectation%20functions%2C%20running%20tests.ipynb and
# https://github.com/marcotcr/checklist/blob/master/notebooks/tutorials/4.%20The%20CheckList%20process.ipynb and 
# https://github.com/marcotcr/checklist/blob/master/notebooks/Test%20Suite%20Examples.ipynb
# with major changes

# code for confusion matrix visualisations partly taken from
# https://matplotlib.org/stable/api/pyplot_summary.html and
# https://www.w3schools.com/python/python_ml_confusion_matrix.asp
# with minor changes

# %%
# notes
# hard to find parallel adjective pairs where standard German and Bavarian are different -> focus on only three pairs per sentiment

# test sentences only work with predicative adjective constructions to avoid issues with inflection of the pre-chosen adjectives in standard German and Bavarian

# the tests give a good first glance at the performance, but no further error informations. 
# further visualisations: confusion matrix to see which labels were wrongly predicted as which other label
# no out-of-the-box method to access all fails, that would be handy

# running the suite with a prediction function does not allow for access to the scores, so if you need the scores themselves, you have to predict to a file
# and run the suite from the file, so that you can use the scores for further analyses again later too

# result analysis English:
# some fails have to do with weather. in those cases, the sentences are labeled as neutral instead of negative. it is actually debatable if this is a fail, since
# the perception of weather is very subjective and - unless it's a natural disaster - there is no "objectively bad" weather. in the context of this test it is
# questionable whether this is a true fail or rather a design fail of the test
# sents with "stupid" tend to be labeled as negative
# the model has problems with the 4th experiment (making negative sentences positive with positive phrases)
#
# Q: do these errors show in German and Bavarian?
#

# %%
# # if pip installation of CheckList fails, run these commands in the terminal:
# git clone https://github.com/marcotcr/checklist.git
# cd checklist/
# pip install -e .

# %%
# # for modernbert model install this transformers version
# !pip install "git+https://github.com/huggingface/transformers.git@6e0515e99c39444caae39472ee1b2fd76ece32f1" --upgrade

# %%
from checklist.editor import Editor
from checklist.test_types import MFT
from checklist.test_suite import TestSuite
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from germansentiment import SentimentModel
import torch
import math
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# initialise CheckList Editor objects
eng_editor = Editor() # default language = English
deu_editor = Editor(language="german")

# initialise CheckList TestSuite for running the tests
eng_suite = TestSuite()
deu_suite = TestSuite()
deu_suite_gerbert = TestSuite()
bar_suite = TestSuite()
bar_suite_gerbert = TestSuite()

# %%
# linguistic resources
# words chosen from the CheckList Editor suggestions

# parallel adjective lists for data creation
eng_pos = ["good", "nice", "great"]
deu_pos = ["gut", "schön", "super"]
bar_pos = ["guad", "schee", "subba"]

eng_neg = ["bad", "boring", "stupid"]
deu_neg = ["schlecht", "langweilig", "blöd"]
bar_neg = ["schlecht", "fad", "bled"]

# parallel noun lists for data creation
# picked from Editor suggestions in such a way that mostly all words are different
eng_noun = ["game", "site", "picture", "book", "story", "man", "world", "city", "time", "weather", "life"]

# standard German and Bavarian examples with determiners to avoid errors
deu_noun = [
    ("Das", "Spiel"), ("Die", "Seite"), ("Das", "Bild"), ("Das", "Buch"), ("Die", "Geschichte"), 
    ("Der", "Mann"), ("Die", "Welt"), ("Die", "Stadt"), ("Die", "Zeit"), ("Das", "Wetter"), ("Das", "Leben")
    ]
deu_noun_lower = [
    ("das", "Spiel"), ("die", "Seite"), ("das", "Bild"), ("das", "Buch"), ("die", "Geschichte"), 
    ("der", "Mann"), ("die", "Welt"), ("die", "Stadt"), ("die", "Zeit"), ("das", "Wetter"), ("das", "Leben")
    ]

# bavarian determiners are with spaces to handle "d'" and "s'" determiners
bar_noun = [
    ("Des ", "Spui"), ("De ", "Seitn"), ("Des ", "Buidl"), ("Des ", "Buach"), ("De ", "Gschicht"), 
    ("Der ", "Mo"), ("D'", "Weid"), ("D'", "Stod"), ("D'", "Zeid"), ("S'", "Weda"), ("S'", "Lebm")
    ] 
bar_noun_lower = [
    ("des ", "Spui"), ("de ", "Seitn"), ("des ", "Buidl"), ("des ", "Buach"), ("de ", "Gschicht"), 
    ("der ", "Mo"), ("d'", "Weid"), ("d'", "Stod"), ("d'", "Zeid"), ("s'", "Weda"), ("s'", "Lebm")
    ] 

# negative phrases
eng_neg_p = ["I hate that", "I don't like that"]
deu_neg_p = ["Ich hasse, dass", "Ich mag nicht, dass"]
bar_neg_p = ["I hass des, wenn", "I mog des ned, wenn"] # bavarian constructions work a bit differently than standard German

# positive phrases
eng_pos_p = ["I like that", "I love that"]
deu_pos_p = ["Ich mag, dass", "Ich liebe, dass"]
bar_pos_p = ["I mog des, wenn", "I liebs, wenn"]

# %% [markdown]
# ## Word Suggestions

# %%
# get adj suggestions from the CheckList Editors in German and English
print("English adj suggestions: ")
print(eng_editor.suggest("This is a {mask} {noun}.", noun=["book", "movie"])[:20], "\n") 

print("German adj suggestions: ")
print(deu_editor.suggest("Das ist ein {mask} Buch.")[:20]) 
print(deu_editor.suggest("Das ist ein {mask} Film.")[:20])
# Out:
# English adj suggestions:
# ['great', 'good', 'wonderful', 'beautiful', 'fantastic', 'terrible', 'fascinating', 'big', 'nice', 'bad', 'long', 'fun', 'scary', 'terrific', 'tough', 'short', 'serious', 'huge', 'remarkable', 'new']
#
# German adj suggestions:
# ['gutes', 'neues', 'großes', 'kleines', 'starkes', 'politisches', 'anderes', 'wichtiges', 'ganzes', 'besonderes', 'altes', 'deutsches', 'eigenes', 'super', 'weiteres', 'solches', 'zweites', 'einziges', 'letztes', 'erstes']
# ['guter', 'schlechter', 'großer', 'schöner', 'super', 'wichtiger', 'deutscher', 'schwieriger', 'historischer', 'neuer', 'kleiner', 'politischer', 'typischer', 'anderer', 'besonderer', 'amerikanischer', 'klassischer', 'einfacher', 'internationaler', 'langer']

# %%
# get noun suggestions from the CheckList Editors in German and English
# english suggestions
print("English noun suggestions: ")
print(eng_editor.suggest("This {mask} is {pos}.", pos=eng_pos)[:10]) 
print(eng_editor.suggest("This {mask} is {neg}.", neg=eng_neg)[:10], "\n") 

# suggestions for standard German with different determiners
print("German noun suggestions: ")
print("Der", deu_editor.suggest("Der {mask} ist {pos}.", pos=deu_pos)[:10])
print("Der", deu_editor.suggest("Der {mask} ist {neg}.", neg=deu_neg)[:10])
print("Die", deu_editor.suggest("Die {mask} ist {pos}.", pos=deu_pos)[:10])
print("Die", deu_editor.suggest("Die {mask} ist {neg}.", neg=deu_neg)[:10])
print("Das", deu_editor.suggest("Das {mask} ist {pos}.", pos=deu_pos)[:10])
print("Das", deu_editor.suggest("Das {mask} ist {neg}.", neg=deu_neg)[:10])
# Out:
# English noun suggestions:
# ['game', 'one', 'stuff', 'book', 'article', 'video', 'post', 'movie', 'code', 'thing']
# ['post', 'article', 'game', 'stuff', 'video', 'movie', 'list', 'shit', 'thing', 'book']
#
# German noun suggestions:
# Der ['Preis', 'Job', 'Platz', 'Service', 'Abend', 'Wind', 'Rest', 'Sieg', 'Auftritt', 'Eindruck']
# Der ['Rest', 'Job', 'Film', 'Ton', 'Fußball', 'Mann', 'Preis', 'Markt', 'Anfang', 'Fall']
# Die ['Stimmung', 'Atmosphäre', 'Situation', 'Sache', 'Resonanz', 'Lage', 'Idee', 'Antwort', 'Qualität', 'Zusammenarbeit']
# Die ['Stimmung', 'Sache', 'Situation', 'Lage', 'Welt', 'Idee', 'Musik', 'Antwort', 'Geschichte', 'Zeit']
# Das ['Ergebnis', 'Wetter', 'alles', 'Leben', 'Angebot', 'hier', 'Spiel', 'Resultat', 'Stadion', 'Essen']
# Das ['Ergebnis', 'alles', 'Wetter', 'Leben', 'aber', 'Spiel', 'Ganze', 'hier', 'Auto', 'Geschäft']

# %% [markdown]
# ## Test Creation

# %%
# Sanity tests
# English
data = eng_editor.template("The {noun} is {adj}.", noun=eng_noun, adj=eng_pos, labels=2) # positive samples
data += eng_editor.template("The {noun} is {adj}.", noun=eng_noun, adj=eng_neg, labels=0) # negative samples
test = MFT(**data)
eng_suite.add(test, "ENG: Sanity Check", "Negation", "Simple positive and negative sentences.", overwrite=True)

# German
data = deu_editor.template("{detnoun[0]} {detnoun[1]} ist {adj}.", detnoun=deu_noun, adj=deu_pos, labels=2) # positive samples
data += eng_editor.template("{detnoun[0]} {detnoun[1]} ist {adj}.", detnoun=deu_noun, adj=deu_neg, labels=0) # negative samples
test = MFT(**data)
deu_suite.add(test, "DEU: Sanity Check", "Negation", "Simple positive and negative sentences.", overwrite=True)
deu_suite_gerbert.add(test, "DEU: Sanity Check", "Negation", "Simple positive and negative sentences.", overwrite=True)

# Bavarian
data = deu_editor.template("{detnoun[0]}{detnoun[1]} is {adj}.", detnoun=bar_noun, adj=bar_pos, labels=2) # positive samples
data += eng_editor.template("{detnoun[0]}{detnoun[1]} is {adj}.", detnoun=bar_noun, adj=bar_pos, labels=0) # negative samples
test = MFT(**data)
bar_suite.add(test, "BAR: Sanity Check", "Negation", "Simple positive and negative sentences.", overwrite=True)
bar_suite_gerbert.add(test, "BAR: Sanity Check", "Negation", "Simple positive and negative sentences.", overwrite=True)

# %%
# English tests

# test for negated positive examples, expectation: negative (0)
# e.g. The game is not good.
data01 = eng_editor.template("The {noun} is not {adj}.", noun=eng_noun, adj=eng_pos, labels=0) # not pos = negative
test = MFT(**data01)
eng_suite.add(test, "ENG: Positive Adjective Negations --> Negative", "Negation", "Sentences with negated positive adjectives.", overwrite=True)

# test for negations of positive phrases, expectation: negative (0)
# e.g. I hate that the game is good.
data02 = eng_editor.template("{p} the {noun} is {adj}.", p=eng_neg_p, noun=eng_noun, adj=eng_pos, labels=0)
test = MFT(**data02)
eng_suite.add(test, "ENG: Positive Phrase Negations --> Negative", "Negation", "Negations of positive sentences.", overwrite=True)

# test for negated negative adjectives, expectation: positive (1) (or 2)
# e.g. The game is not bad.
data03 = eng_editor.template("The {noun} is not {adj}.", noun=eng_noun, adj=eng_neg, labels=2) # not neg = positive
test = MFT(**data03)
eng_suite.add(test, "ENG: Negative Adjective Negations --> Positive", "Negation", "Sentences with negated negative adjectives.", overwrite=True)

# test for positive additional phrases to negative phrases, expectation: positive (1) (or 2)
# e.g. I like that the game is bad.
data04 = eng_editor.template("{p} the {noun} is {adj}.", p=eng_pos_p, noun=eng_noun, adj=eng_neg, labels=2)
test = MFT(**data04)
eng_suite.add(test, "ENG: Negative Phrases with Positive Additions --> Positive", "Negation", "Positive additions to negative sentences.", overwrite=True)

# %%
# German tests

# test for negated positive examples, expectation: negative (0)
# e.g. Das Spiel ist nicht gut.
data = deu_editor.template("{detnoun[0]} {detnoun[1]} ist nicht {adj}.", detnoun=deu_noun, adj=deu_pos, labels=0) # not pos = negative
test = MFT(**data)
deu_suite.add(test, "DEU: Positive Adjective Negations --> Negative", "Negation", "Sentences with negated positive adjectives in Standard German.", overwrite=True)
deu_suite_gerbert.add(test, "DEU: Positive Adjective Negations --> Negative", "Negation", "Sentences with negated positive adjectives in Standard German.", overwrite=True)

# test for negations of positive phrases, expectation: negative (0)
# e.g. Ich hasse, dass das Spiel gut ist.
data = deu_editor.template("{p} {detnoun[0]} {detnoun[1]} {adj} ist.", p=deu_neg_p, detnoun=deu_noun_lower, adj=deu_pos, labels=0)
test = MFT(**data)
deu_suite.add(test, "DEU: Positive Phrase Negations --> Negative", "Negation", "Negations of positive sentences in Standard German.", overwrite=True)
deu_suite_gerbert.add(test, "DEU: Positive Phrase Negations --> Negative", "Negation", "Negations of positive sentences in Standard German.", overwrite=True)

# test for negated negative adjectives, expectation: positive (1) (or 2)
# e.g. Das Spiel ist nicht schlecht.
data = deu_editor.template("{detnoun[0]} {detnoun[1]} ist nicht {adj}.", detnoun=deu_noun, adj=deu_neg, labels=2) # not neg = positive
test = MFT(**data)
deu_suite.add(test, "DEU: Negative Adjective Negations --> Positive", "Negation", "Sentences with negated negative adjectives in Standard German.", overwrite=True)
deu_suite_gerbert.add(test, "DEU: Negative Adjective Negations --> Positive", "Negation", "Sentences with negated negative adjectives in Standard German.", overwrite=True)

# test for positive additional phrases to negative phrases, expectation: positive (1) (or 2)
# e.g. Ich mag, dass das Spiel schlecht ist.
data = deu_editor.template("{p} {detnoun[0]} {detnoun[1]} {adj} ist.", p=deu_pos_p, detnoun=deu_noun_lower, adj=deu_neg, labels=2)
test = MFT(**data)
deu_suite.add(test, "DEU: Negative Phrases with Positive Additions --> Positive", "Negation", "Positive additions to negative sentences in Standard German.", overwrite=True)
deu_suite_gerbert.add(test, "DEU: Negative Phrases with Positive Additions --> Positive", "Negation", "Positive additions to negative sentences in Standard German.", overwrite=True)

# %%
# Bavarian tests

# test for negated positive examples, expectation: negative (0)
# e.g. Des Spui is ned guad.
data = deu_editor.template("{detnoun[0]}{detnoun[1]} is ned {adj}.", detnoun=bar_noun, adj=bar_pos, labels=0) # not pos = negative
test = MFT(**data)
bar_suite.add(test, "BAR: Positive Adjective Negations --> Negative", "Negation", "Sentences with negated positive adjectives in Bavarian.", overwrite=True)
bar_suite_gerbert.add(test, "BAR: Positive Adjective Negations --> Negative", "Negation", "Sentences with negated positive adjectives in Bavarian.", overwrite=True)

# test for negations of positive phrases, expectation: negative (0)
# e.g. I hass des, wenn des Spui guad ist.
data = deu_editor.template("{p} {detnoun[0]}{detnoun[1]} {adj} ist.", p=bar_neg_p, detnoun=bar_noun_lower, adj=bar_pos, labels=0)
test = MFT(**data)
bar_suite.add(test, "BAR: Positive Phrase Negations --> Negative", "Negation", "Negations of positive sentences in Bavarian.", overwrite=True)
bar_suite_gerbert.add(test, "BAR: Positive Phrase Negations --> Negative", "Negation", "Negations of positive sentences in Bavarian.", overwrite=True)

# test for negated negative adjectives, expectation: positive (1) (or 2)
# e.g. Des Spui ist nicht schlecht.
data = deu_editor.template("{detnoun[0]}{detnoun[1]} ist nicht {adj}.", detnoun=bar_noun, adj=bar_neg, labels=2) # not neg = positive
test = MFT(**data)
bar_suite.add(test, "BAR: Negative Adjective Negations --> Positive", "Negation", "Sentences with negated negative adjectives in Bavarian.", overwrite=True)
bar_suite_gerbert.add(test, "BAR: Negative Adjective Negations --> Positive", "Negation", "Sentences with negated negative adjectives in Bavarian.", overwrite=True)

# test for positive additional phrases to negative phrases, expectation: positive (1) (or 2)
# e.g. I mog des, wenn des Spui schlecht ist.
data = deu_editor.template("{p} {detnoun[0]}{detnoun[1]} {adj} ist.", p=bar_pos_p, detnoun=bar_noun_lower, adj=bar_neg, labels=2)
test = MFT(**data)
bar_suite.add(test, "BAR: Negative Phrases with Positive Additions --> Positive", "Negation", "Positive additions to negative sentences in Bavarian.", overwrite=True)
bar_suite_gerbert.add(test, "BAR: Negative Phrases with Positive Additions --> Positive", "Negation", "Positive additions to negative sentences in Bavarian.", overwrite=True)

# %% [markdown]
# ## Model Predictions Generation

# %% [markdown]
# ### with modernBERT = multilingual encoder-based model

# %%
# load multilingual sentiment analysis model
model_name = "clapAI/modernBERT-base-multilingual-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# initialise pipeline for predictions
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_float32_matmul_precision("high") # for better performance with TensorFloat32 tensor cores
pipe = pipeline("text-classification", model=model, tokenizer=tokenizer, device=device, top_k=None)

idx2lbl = model.config.id2label
lbl2idx = model.config.label2id
print(lbl2idx)
print(idx2lbl)

# functions for predictions and running the TestSuites
def predict_to_file(data, preds):
    # read data and predict
    with open(data, "r") as f:
        data = [line.strip() for line in f.readlines()]
    
    raw_preds = pipe(data)

    # write results in correct CheckList format to a file
    with open(preds, "w") as f:
        f.write("prediction positive neutral negative\n")
        for result in raw_preds:
            positive = result[0]
            neutral = result[1]
            negative = result[2]

            max_pred = max([negative, positive, neutral], key=lambda x: x["score"])
            max_label = max_pred["label"]

            f.write(f"{lbl2idx[max_label]} {positive["score"]} {neutral["score"]} {negative["score"]}\n")
# Out:
# Device set to use cuda
# {'negative': 0, 'neutral': 1, 'positive': 2}
# {0: 'negative', 1: 'neutral', 2: 'positive'}

# %%
# Generate English predictions
eng_data_file = "/tmp/eng_data.txt"
eng_predictions_file = "/tmp/eng_predictions_bert.txt"

eng_suite.to_raw_file(eng_data_file)
predict_to_file(eng_data_file, eng_predictions_file)

# %%
# Generate German predictions
deu_data_file = "/tmp/deu_data.txt"
deu_predictions_file = "/tmp/deu_predictions_bert.txt"

deu_suite.to_raw_file(deu_data_file)
predict_to_file(deu_data_file, deu_predictions_file)

# %%
# Generate Bavarian predictions
bar_data_file = "/tmp/bar_data.txt"
bar_predictions_file = "/tmp/bar_predictions_bert.txt"

bar_suite.to_raw_file(bar_data_file)
predict_to_file(bar_data_file, bar_predictions_file)

# %% [markdown]
# ### with German Sentiment Bert = monolingual German encoder-based model

# %%
# load monolingual German model
model_gerbert = SentimentModel()

def predict_to_file_germanbert(data, preds):
    # read data and predict
    with open(data, "r") as f:
        data = [line.strip() for line in f.readlines()]
    
    raw_labels, raw_preds = model_gerbert.predict_sentiment(data, output_probabilities=True)

    # write results in correct CheckList format to a file
    with open(preds, "w") as f:
        f.write("prediction positive neutral negative\n")
        for label, result in zip(raw_labels, raw_preds):  
            positive = result[0][1]
            neutral = result[2][1]
            negative = result[1][1]

            f.write(f"{lbl2idx[label]} {positive} {neutral} {negative}\n")

# %%
# Generate German predictions
deu_predictions_file_gerbert = "/tmp/deu_predictions_gerbert.txt"

deu_suite_gerbert.to_raw_file(deu_data_file)
predict_to_file_germanbert(deu_data_file, deu_predictions_file_gerbert)

# %%
# Generate Bavarian predictions
bar_predictions_file_gerbert = "/tmp/bar_predictions_gerbert.txt"

bar_suite_gerbert.to_raw_file(bar_data_file)
predict_to_file_germanbert(bar_data_file, bar_predictions_file_gerbert)

# %% [markdown]
# ## CheckList Testing

# %%
def format_example(x, pred, conf, label, meta=None): 
    return f"Sentence: {x}\nGold: {idx2lbl[label]}\tPredicted: {idx2lbl[pred]}"

# %%
# Run English TestSuite
eng_suite.run_from_file(eng_predictions_file, file_format="pred_and_softmax", ignore_header=True, overwrite=True)

eng_suite.summary(format_example_fn = format_example)
# Out:
# Negation
#
# ENG: Sanity Check
# Test cases:      66
# Fails (rate):    3 (4.5%)
#
# Example fails:
# Sentence: The weather is boring.
# Gold: negative	Predicted: neutral
# ----
# Sentence: The weather is bad.
# Gold: negative	Predicted: neutral
# ----
# Sentence: The weather is good.
# Gold: positive	Predicted: neutral
# ----
#
#
# ENG: Positive Adjective Negations --> Negative
# Test cases:      33
# Fails (rate):    3 (9.1%)
#
# Example fails:
# Sentence: The weather is not nice.
# Gold: negative	Predicted: neutral
# ----
# Sentence: The weather is not great.
# Gold: negative	Predicted: neutral
# ----
# Sentence: The weather is not good.
# Gold: negative	Predicted: neutral
# ----
#
#
# ENG: Positive Phrase Negations --> Negative
# Test cases:      66
# Fails (rate):    3 (4.5%)
#
# Example fails:
# Sentence: I hate that the weather is good.
# Gold: negative	Predicted: neutral
# ----
# Sentence: I hate that the weather is nice.
# Gold: negative	Predicted: neutral
# ----
# Sentence: I hate that the weather is great.
# Gold: negative	Predicted: neutral
# ----
#
#
# ENG: Negative Adjective Negations --> Positive
# Test cases:      33
# Fails (rate):    13 (39.4%)
#
# Example fails:
# Sentence: The city is not bad.
# Gold: positive	Predicted: neutral
# ----
# Sentence: The life is not bad.
# Gold: positive	Predicted: neutral
# ----
# Sentence: The weather is not bad.
# Gold: positive	Predicted: neutral
# ----
#
#
# ENG: Negative Phrases with Positive Additions --> Positive
# Test cases:      66
# Fails (rate):    53 (80.3%)
#
# Example fails:
# Sentence: I like that the site is stupid.
# Gold: positive	Predicted: negative
# ----
# Sentence: I love that the site is bad.
# Gold: positive	Predicted: negative
# ----
# Sentence: I like that the game is bad.
# Gold: positive	Predicted: negative
# ----

# %%
# Run German TestSuite
deu_suite.run_from_file(deu_predictions_file, file_format="pred_and_softmax", ignore_header=True, overwrite=True)

deu_suite.summary(format_example_fn = format_example)
# Out:
# Negation
#
# DEU: Sanity Check
# Test cases:      66
# Fails (rate):    0 (0.0%)
#
#
# DEU: Positive Adjective Negations --> Negative
# Test cases:      33
# Fails (rate):    1 (3.0%)
#
# Example fails:
# Sentence: Das Wetter ist nicht super.
# Gold: negative	Predicted: neutral
# ----
#
#
# DEU: Positive Phrase Negations --> Negative
# Test cases:      66
# Fails (rate):    35 (53.0%)
#
# Example fails:
# Sentence: Ich hasse, dass die Stadt schön ist.
# Gold: negative	Predicted: positive
# ----
# Sentence: Ich hasse, dass das Bild gut ist.
# Gold: negative	Predicted: positive
# ----
# Sentence: Ich hasse, dass das Wetter gut ist.
# Gold: negative	Predicted: positive
# ----
#
#
# DEU: Negative Adjective Negations --> Positive
# Test cases:      33
# Fails (rate):    2 (6.1%)
#
# Example fails:
# Sentence: Das Bild ist nicht langweilig.
# Gold: positive	Predicted: negative
# ----
# Sentence: Das Bild ist nicht schlecht.
# Gold: positive	Predicted: neutral
# ----
#
#
# DEU: Negative Phrases with Positive Additions --> Positive
# Test cases:      66
# Fails (rate):    47 (71.2%)
#
# Example fails:
# Sentence: Ich mag, dass der Mann langweilig ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: Ich mag, dass das Leben langweilig ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: Ich mag, dass das Spiel blöd ist.
# Gold: positive	Predicted: negative
# ----

# %%
# Run Bavarian TestSuite
bar_suite.run_from_file(bar_predictions_file, file_format="pred_and_softmax", ignore_header=True, overwrite=True)

bar_suite.summary(format_example_fn = format_example)
# Out:
# Negation
#
# BAR: Sanity Check
# Test cases:      66
# Fails (rate):    37 (56.1%)
#
# Example fails:
# Sentence: De Gschicht is guad.
# Gold: positive	Predicted: negative
# ----
# Sentence: D'Stod is subba.
# Gold: positive	Predicted: negative
# ----
# Sentence: D'Zeid is schee.
# Gold: positive	Predicted: neutral
# ----
#
#
# BAR: Positive Adjective Negations --> Negative
# Test cases:      33
# Fails (rate):    33 (100.0%)
#
# Example fails:
# Sentence: Des Buidl is ned subba.
# Gold: negative	Predicted: neutral
# ----
# Sentence: De Gschicht is ned subba.
# Gold: negative	Predicted: neutral
# ----
# Sentence: Des Buidl is ned schee.
# Gold: negative	Predicted: neutral
# ----
#
#
# BAR: Positive Phrase Negations --> Negative
# Test cases:      66
# Fails (rate):    3 (4.5%)
#
# Example fails:
# Sentence: I mog des ned, wenn des Buach subba ist.
# Gold: negative	Predicted: neutral
# ----
# Sentence: I mog des ned, wenn der Mo subba ist.
# Gold: negative	Predicted: neutral
# ----
# Sentence: I mog des ned, wenn d'Stod subba ist.
# Gold: negative	Predicted: neutral
# ----
#
#
# BAR: Negative Adjective Negations --> Positive
# Test cases:      33
# Fails (rate):    12 (36.4%)
#
# Example fails:
# Sentence: D'Stod ist nicht bled.
# Gold: positive	Predicted: negative
# ----
# Sentence: Des Buach ist nicht bled.
# Gold: positive	Predicted: negative
# ----
# Sentence: Des Buidl ist nicht fad.
# Gold: positive	Predicted: neutral
# ----
#
#
# BAR: Negative Phrases with Positive Additions --> Positive
# Test cases:      66
# Fails (rate):    58 (87.9%)
#
# Example fails:
# Sentence: I mog des, wenn de Seitn bled ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: I mog des, wenn d'Zeid schlecht ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: I mog des, wenn s'Lebm bled ist.
# Gold: positive	Predicted: negative
# ----

# %%
# Run German TestSuite on German Sentiment Bert results
deu_suite_gerbert.run_from_file(deu_predictions_file_gerbert, file_format="pred_and_softmax", ignore_header=True, overwrite=True)

deu_suite_gerbert.summary(format_example_fn = format_example)
# Out:
# Negation
#
# DEU: Sanity Check
# Test cases:      66
# Fails (rate):    7 (10.6%)
#
# Example fails:
# Sentence: Das Buch ist schön.
# Gold: positive	Predicted: neutral
# ----
# Sentence: Das Buch ist gut.
# Gold: positive	Predicted: neutral
# ----
# Sentence: Das Buch ist blöd.
# Gold: negative	Predicted: neutral
# ----
#
#
# DEU: Positive Adjective Negations --> Negative
# Test cases:      33
# Fails (rate):    2 (6.1%)
#
# Example fails:
# Sentence: Das Buch ist nicht super.
# Gold: negative	Predicted: neutral
# ----
# Sentence: Das Buch ist nicht schön.
# Gold: negative	Predicted: neutral
# ----
#
#
# DEU: Positive Phrase Negations --> Negative
# Test cases:      66
# Fails (rate):    12 (18.2%)
#
# Example fails:
# Sentence: Ich mag nicht, dass das Leben gut ist.
# Gold: negative	Predicted: neutral
# ----
# Sentence: Ich hasse, dass das Buch gut ist.
# Gold: negative	Predicted: neutral
# ----
# Sentence: Ich mag nicht, dass die Geschichte schön ist.
# Gold: negative	Predicted: neutral
# ----
#
#
# DEU: Negative Adjective Negations --> Positive
# Test cases:      33
# Fails (rate):    9 (27.3%)
#
# Example fails:
# Sentence: Das Leben ist nicht blöd.
# Gold: positive	Predicted: neutral
# ----
# Sentence: Das Buch ist nicht langweilig.
# Gold: positive	Predicted: neutral
# ----
# Sentence: Die Geschichte ist nicht langweilig.
# Gold: positive	Predicted: neutral
# ----
#
#
# DEU: Negative Phrases with Positive Additions --> Positive
# Test cases:      66
# Fails (rate):    35 (53.0%)
#
# Example fails:
# Sentence: Ich mag, dass das Bild blöd ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: Ich mag, dass die Welt schlecht ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: Ich mag, dass die Welt blöd ist.
# Gold: positive	Predicted: negative
# ----

# %%
# Run Bavarian TestSuite on German Sentiment Bert results
bar_suite_gerbert.run_from_file(bar_predictions_file_gerbert, file_format="pred_and_softmax", ignore_header=True, overwrite=True)

bar_suite_gerbert.summary(format_example_fn = format_example)
# Out:
# Negation
#
# BAR: Sanity Check
# Test cases:      66
# Fails (rate):    33 (50.0%)
#
# Example fails:
# Sentence: D'Zeid is subba.
# Gold: negative	Predicted: positive
# ----
# Sentence: D'Weid is guad.
# Gold: negative	Predicted: positive
# ----
# Sentence: De Gschicht is guad.
# Gold: negative	Predicted: positive
# ----
#
#
# BAR: Positive Adjective Negations --> Negative
# Test cases:      33
# Fails (rate):    0 (0.0%)
#
#
# BAR: Positive Phrase Negations --> Negative
# Test cases:      66
# Fails (rate):    2 (3.0%)
#
# Example fails:
# Sentence: I mog des ned, wenn des Buidl subba ist.
# Gold: negative	Predicted: neutral
# ----
# Sentence: I mog des ned, wenn des Buidl guad ist.
# Gold: negative	Predicted: neutral
# ----
#
#
# BAR: Negative Adjective Negations --> Positive
# Test cases:      33
# Fails (rate):    17 (51.5%)
#
# Example fails:
# Sentence: De Seitn ist nicht bled.
# Gold: positive	Predicted: negative
# ----
# Sentence: Der Mo ist nicht fad.
# Gold: positive	Predicted: negative
# ----
# Sentence: Der Mo ist nicht bled.
# Gold: positive	Predicted: neutral
# ----
#
#
# BAR: Negative Phrases with Positive Additions --> Positive
# Test cases:      66
# Fails (rate):    33 (50.0%)
#
# Example fails:
# Sentence: I mog des, wenn s'Lebm schlecht ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: I mog des, wenn d'Zeid bled ist.
# Gold: positive	Predicted: negative
# ----
# Sentence: I mog des, wenn d'Zeid fad ist.
# Gold: positive	Predicted: negative
# ----

# %% [markdown]
# ## Further Analyses

# %%
# show all fails instead of only the three example fails

def show_all_fails(testsuite):
    for test_name, test in testsuite.tests.items():
        test_results = test.results
        test_data = list(enumerate(test.data))

        print(f"\nTest: {test_name}")

        for i, text in test_data:
            pred_label = idx2lbl[test_results["preds"][i]]
            pred_score = round(test_results["confs"][i][0], 2)

            if test_results["passed"][i] == False:
                print(f"Predicted: {pred_label}\t\tScore: {pred_score}\t\tText: {text}")

show_all_fails(eng_suite)
show_all_fails(deu_suite)
show_all_fails(bar_suite)
# Out:
# Test: ENG: Sanity Check
# Predicted: neutral		Score: 0.49		Text: The weather is good.
# Predicted: neutral		Score: 0.57		Text: The weather is bad.
# Predicted: neutral		Score: 0.51		Text: The weather is boring.
#
# Test: ENG: Positive Adjective Negations --> Negative
# Predicted: neutral		Score: 0.63		Text: The weather is not good.
# Predicted: neutral		Score: 0.66		Text: The weather is not nice.
# Predicted: neutral		Score: 0.74		Text: The weather is not great.
#
# Test: ENG: Positive Phrase Negations --> Negative
# Predicted: neutral		Score: 0.55		Text: I hate that the weather is good.
# Predicted: neutral		Score: 0.56		Text: I hate that the weather is nice.
# Predicted: neutral		Score: 0.53		Text: I hate that the weather is great.
#
# Test: ENG: Negative Adjective Negations --> Positive
# Predicted: negative		Score: 0.68		Text: The site is not stupid.
# Predicted: negative		Score: 0.5		Text: The picture is not stupid.
# Predicted: neutral		Score: 0.41		Text: The man is not bad.
# Predicted: neutral		Score: 0.43		Text: The world is not stupid.
# Predicted: neutral		Score: 0.66		Text: The city is not bad.
# Predicted: neutral		Score: 0.43		Text: The city is not boring.
# Predicted: negative		Score: 0.52		Text: The city is not stupid.
# Predicted: neutral		Score: 0.4		Text: The time is not stupid.
# Predicted: neutral		Score: 0.74		Text: The weather is not bad.
# Predicted: neutral		Score: 0.71		Text: The weather is not boring.
# Predicted: neutral		Score: 0.86		Text: The weather is not stupid.
# Predicted: neutral		Score: 0.53		Text: The life is not bad.
# Predicted: negative		Score: 0.4		Text: The life is not stupid.
#
# Test: ENG: Negative Phrases with Positive Additions --> Positive
# Predicted: negative		Score: 0.68		Text: I like that the game is bad.
# Predicted: negative		Score: 0.73		Text: I like that the game is stupid.
# Predicted: negative		Score: 0.81		Text: I like that the site is bad.
# Predicted: negative		Score: 0.82		Text: I like that the site is boring.
# Predicted: negative		Score: 0.73		Text: I like that the site is stupid.
# Predicted: negative		Score: 0.62		Text: I like that the picture is bad.
# Predicted: negative		Score: 0.46		Text: I like that the picture is stupid.
# Predicted: negative		Score: 0.81		Text: I like that the book is bad.
# Predicted: negative		Score: 0.69		Text: I like that the book is boring.
# Predicted: negative		Score: 0.71		Text: I like that the book is stupid.
# Predicted: negative		Score: 0.89		Text: I like that the story is bad.
# Predicted: negative		Score: 0.72		Text: I like that the story is boring.
# Predicted: negative		Score: 0.92		Text: I like that the story is stupid.
# Predicted: neutral		Score: 0.54		Text: I like that the man is bad.
# Predicted: neutral		Score: 0.48		Text: I like that the man is boring.
# Predicted: neutral		Score: 0.61		Text: I like that the man is stupid.
# Predicted: negative		Score: 0.53		Text: I like that the world is boring.
# Predicted: negative		Score: 0.51		Text: I like that the city is bad.
# Predicted: negative		Score: 0.45		Text: I like that the city is stupid.
# Predicted: neutral		Score: 0.58		Text: I like that the weather is bad.
# Predicted: neutral		Score: 0.53		Text: I like that the weather is boring.
# Predicted: neutral		Score: 0.68		Text: I like that the weather is stupid.
# Predicted: negative		Score: 0.51		Text: I like that the life is bad.
# Predicted: negative		Score: 0.59		Text: I like that the life is boring.
# Predicted: negative		Score: 0.81		Text: I love that the game is bad.
# Predicted: negative		Score: 0.94		Text: I love that the game is boring.
# Predicted: negative		Score: 0.97		Text: I love that the game is stupid.
# Predicted: negative		Score: 0.85		Text: I love that the site is bad.
# Predicted: negative		Score: 0.94		Text: I love that the site is boring.
# Predicted: negative		Score: 0.9		Text: I love that the site is stupid.
# Predicted: negative		Score: 0.69		Text: I love that the picture is bad.
# Predicted: negative		Score: 0.84		Text: I love that the picture is boring.
# Predicted: negative		Score: 0.91		Text: I love that the picture is stupid.
# Predicted: negative		Score: 0.91		Text: I love that the book is bad.
# Predicted: negative		Score: 0.95		Text: I love that the book is boring.
# Predicted: negative		Score: 0.94		Text: I love that the book is stupid.
# Predicted: negative		Score: 0.68		Text: I love that the story is bad.
# Predicted: negative		Score: 0.94		Text: I love that the story is boring.
# Predicted: negative		Score: 0.96		Text: I love that the story is stupid.
# Predicted: negative		Score: 0.74		Text: I love that the man is boring.
# Predicted: neutral		Score: 0.43		Text: I love that the man is stupid.
# Predicted: negative		Score: 0.78		Text: I love that the world is boring.
# Predicted: negative		Score: 0.65		Text: I love that the world is stupid.
# Predicted: negative		Score: 0.49		Text: I love that the city is bad.
# Predicted: negative		Score: 0.71		Text: I love that the city is boring.
# Predicted: negative		Score: 0.61		Text: I love that the city is stupid.
# Predicted: negative		Score: 0.58		Text: I love that the time is stupid.
# Predicted: neutral		Score: 0.69		Text: I love that the weather is bad.
# Predicted: neutral		Score: 0.53		Text: I love that the weather is boring.
# Predicted: neutral		Score: 0.89		Text: I love that the weather is stupid.
# Predicted: negative		Score: 0.67		Text: I love that the life is bad.
# Predicted: negative		Score: 0.91		Text: I love that the life is boring.
# Predicted: negative		Score: 0.61		Text: I love that the life is stupid.
#
# Test: DEU: Sanity Check
# Predicted: neutral		Score: 0.28		Text: Das Buch ist gut.
# Predicted: neutral		Score: 0.29		Text: Das Buch ist schön.
# Predicted: neutral		Score: 0.1		Text: Das Buch ist super.
# Predicted: neutral		Score: 0.28		Text: Die Geschichte ist schön.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist schlecht.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist langweilig.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist blöd.
#
# Test: DEU: Positive Adjective Negations --> Negative
# Predicted: neutral		Score: 0.0		Text: Das Buch ist nicht schön.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist nicht super.
#
# Test: DEU: Positive Phrase Negations --> Negative
# Predicted: neutral		Score: 0.05		Text: Ich hasse, dass das Buch gut ist.
# Predicted: neutral		Score: 0.01		Text: Ich hasse, dass das Buch schön ist.
# Predicted: neutral		Score: 0.03		Text: Ich hasse, dass das Buch super ist.
# Predicted: positive		Score: 0.51		Text: Ich mag nicht, dass die Seite super ist.
# Predicted: neutral		Score: 0.0		Text: Ich mag nicht, dass das Buch gut ist.
# Predicted: neutral		Score: 0.0		Text: Ich mag nicht, dass das Buch schön ist.
# Predicted: neutral		Score: 0.01		Text: Ich mag nicht, dass das Buch super ist.
# Predicted: neutral		Score: 0.07		Text: Ich mag nicht, dass die Geschichte schön ist.
# Predicted: positive		Score: 0.85		Text: Ich mag nicht, dass die Welt super ist.
# Predicted: positive		Score: 0.68		Text: Ich mag nicht, dass die Stadt super ist.
# Predicted: neutral		Score: 0.02		Text: Ich mag nicht, dass das Leben gut ist.
# Predicted: neutral		Score: 0.05		Text: Ich mag nicht, dass das Leben super ist.
#
# Test: DEU: Negative Adjective Negations --> Positive
# Predicted: neutral		Score: 0.13		Text: Die Seite ist nicht langweilig.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist nicht schlecht.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist nicht langweilig.
# Predicted: neutral		Score: 0.0		Text: Das Buch ist nicht blöd.
# Predicted: neutral		Score: 0.17		Text: Die Geschichte ist nicht schlecht.
# Predicted: neutral		Score: 0.01		Text: Die Geschichte ist nicht langweilig.
# Predicted: neutral		Score: 0.01		Text: Die Geschichte ist nicht blöd.
# Predicted: neutral		Score: 0.01		Text: Die Stadt ist nicht blöd.
# Predicted: neutral		Score: 0.04		Text: Das Leben ist nicht blöd.
#
# Test: DEU: Negative Phrases with Positive Additions --> Positive
# Predicted: negative		Score: 0.04		Text: Ich mag, dass das Spiel schlecht ist.
# Predicted: negative		Score: 0.06		Text: Ich mag, dass das Spiel langweilig ist.
# Predicted: negative		Score: 0.08		Text: Ich mag, dass das Spiel blöd ist.
# Predicted: negative		Score: 0.04		Text: Ich mag, dass die Seite schlecht ist.
# Predicted: negative		Score: 0.06		Text: Ich mag, dass die Seite langweilig ist.
# Predicted: negative		Score: 0.1		Text: Ich mag, dass die Seite blöd ist.
# Predicted: negative		Score: 0.06		Text: Ich mag, dass das Bild schlecht ist.
# Predicted: negative		Score: 0.06		Text: Ich mag, dass das Bild langweilig ist.
# Predicted: negative		Score: 0.07		Text: Ich mag, dass das Bild blöd ist.
# Predicted: neutral		Score: 0.0		Text: Ich mag, dass das Buch schlecht ist.
# Predicted: neutral		Score: 0.01		Text: Ich mag, dass das Buch langweilig ist.
# Predicted: neutral		Score: 0.01		Text: Ich mag, dass das Buch blöd ist.
# Predicted: negative		Score: 0.04		Text: Ich mag, dass die Geschichte schlecht ist.
# Predicted: negative		Score: 0.05		Text: Ich mag, dass die Geschichte langweilig ist.
# Predicted: negative		Score: 0.06		Text: Ich mag, dass die Geschichte blöd ist.
# Predicted: negative		Score: 0.04		Text: Ich mag, dass der Mann schlecht ist.
# Predicted: negative		Score: 0.15		Text: Ich mag, dass der Mann blöd ist.
# Predicted: negative		Score: 0.02		Text: Ich mag, dass die Welt schlecht ist.
# Predicted: negative		Score: 0.05		Text: Ich mag, dass die Welt langweilig ist.
# Predicted: negative		Score: 0.04		Text: Ich mag, dass die Welt blöd ist.
# Predicted: negative		Score: 0.07		Text: Ich mag, dass die Stadt schlecht ist.
# Predicted: negative		Score: 0.32		Text: Ich mag, dass die Stadt blöd ist.
# Predicted: negative		Score: 0.02		Text: Ich mag, dass die Zeit schlecht ist.
# Predicted: negative		Score: 0.26		Text: Ich mag, dass die Zeit langweilig ist.
# Predicted: negative		Score: 0.06		Text: Ich mag, dass die Zeit blöd ist.
# Predicted: negative		Score: 0.04		Text: Ich mag, dass das Wetter schlecht ist.
# Predicted: negative		Score: 0.09		Text: Ich mag, dass das Wetter blöd ist.
# Predicted: neutral		Score: 0.03		Text: Ich mag, dass das Leben schlecht ist.
# Predicted: negative		Score: 0.15		Text: Ich mag, dass das Leben langweilig ist.
# Predicted: negative		Score: 0.11		Text: Ich mag, dass das Leben blöd ist.
# Predicted: negative		Score: 0.32		Text: Ich liebe, dass die Seite schlecht ist.
# Predicted: neutral		Score: 0.01		Text: Ich liebe, dass das Buch schlecht ist.
# Predicted: neutral		Score: 0.05		Text: Ich liebe, dass das Buch blöd ist.
# Predicted: neutral		Score: 0.02		Text: Ich liebe, dass das Leben schlecht ist.
# Predicted: neutral		Score: 0.24		Text: Ich liebe, dass das Leben blöd ist.
#
# Test: BAR: Sanity Check
# Predicted: negative		Score: 0.01		Text: Des Spui is schee.
# Predicted: negative		Score: 0.01		Text: De Seitn is schee.
# Predicted: negative		Score: 0.04		Text: Des Buidl is schee.
# Predicted: negative		Score: 0.02		Text: Des Buach is schee.
# Predicted: negative		Score: 0.02		Text: De Gschicht is schee.
# Predicted: negative		Score: 0.03		Text: Der Mo is schee.
# Predicted: negative		Score: 0.02		Text: D'Weid is schee.
# Predicted: negative		Score: 0.02		Text: D'Stod is schee.
# Predicted: negative		Score: 0.02		Text: D'Zeid is schee.
# Predicted: negative		Score: 0.02		Text: S'Weda is schee.
# Predicted: negative		Score: 0.01		Text: S'Lebm is schee.
# Predicted: positive		Score: 0.93		Text: Des Spui is guad.
# Predicted: positive		Score: 0.92		Text: Des Spui is subba.
# Predicted: positive		Score: 0.94		Text: De Seitn is guad.
# Predicted: positive		Score: 0.79		Text: De Seitn is subba.
# Predicted: positive		Score: 0.87		Text: Des Buidl is guad.
# Predicted: positive		Score: 0.86		Text: Des Buidl is subba.
# Predicted: positive		Score: 0.93		Text: Des Buach is guad.
# Predicted: positive		Score: 0.95		Text: Des Buach is subba.
# Predicted: positive		Score: 0.92		Text: De Gschicht is guad.
# Predicted: positive		Score: 0.89		Text: De Gschicht is subba.
# Predicted: positive		Score: 0.94		Text: Der Mo is guad.
# Predicted: positive		Score: 0.94		Text: Der Mo is subba.
# Predicted: positive		Score: 0.98		Text: D'Weid is guad.
# Predicted: positive		Score: 0.96		Text: D'Weid is subba.
# Predicted: positive		Score: 0.94		Text: D'Stod is guad.
# Predicted: positive		Score: 0.94		Text: D'Stod is subba.
# Predicted: positive		Score: 0.94		Text: D'Zeid is guad.
# Predicted: positive		Score: 0.93		Text: D'Zeid is subba.
# Predicted: positive		Score: 0.96		Text: S'Weda is guad.
# Predicted: positive		Score: 0.96		Text: S'Weda is subba.
# Predicted: positive		Score: 0.95		Text: S'Lebm is guad.
# Predicted: positive		Score: 0.93		Text: S'Lebm is subba.
#
# Test: BAR: Positive Adjective Negations --> Negative
#
# Test: BAR: Positive Phrase Negations --> Negative
# Predicted: neutral		Score: 0.04		Text: I mog des ned, wenn des Buidl guad ist.
# Predicted: neutral		Score: 0.06		Text: I mog des ned, wenn des Buidl subba ist.
#
# Test: BAR: Negative Adjective Negations --> Positive
# Predicted: negative		Score: 0.03		Text: Des Spui ist nicht bled.
# Predicted: negative		Score: 0.07		Text: De Seitn ist nicht fad.
# Predicted: negative		Score: 0.03		Text: De Seitn ist nicht bled.
# Predicted: negative		Score: 0.42		Text: Des Buidl ist nicht schlecht.
# Predicted: neutral		Score: 0.01		Text: Des Buidl ist nicht fad.
# Predicted: neutral		Score: 0.0		Text: Des Buidl ist nicht bled.
# Predicted: negative		Score: 0.38		Text: Des Buach ist nicht fad.
# Predicted: negative		Score: 0.05		Text: Des Buach ist nicht bled.
# Predicted: neutral		Score: 0.13		Text: De Gschicht ist nicht fad.
# Predicted: negative		Score: 0.04		Text: De Gschicht ist nicht bled.
# Predicted: negative		Score: 0.22		Text: Der Mo ist nicht fad.
# Predicted: neutral		Score: 0.01		Text: Der Mo ist nicht bled.
# Predicted: negative		Score: 0.03		Text: D'Weid ist nicht bled.
# Predicted: negative		Score: 0.04		Text: D'Stod ist nicht bled.
# Predicted: negative		Score: 0.03		Text: D'Zeid ist nicht bled.
# Predicted: negative		Score: 0.02		Text: S'Weda ist nicht bled.
# Predicted: negative		Score: 0.02		Text: S'Lebm ist nicht bled.
#
# Test: BAR: Negative Phrases with Positive Additions --> Positive
# Predicted: negative		Score: 0.04		Text: I mog des, wenn des Spui schlecht ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn des Spui fad ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn des Spui bled ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn de Seitn schlecht ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn de Seitn fad ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn de Seitn bled ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn des Buidl schlecht ist.
# Predicted: negative		Score: 0.07		Text: I mog des, wenn des Buidl fad ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn des Buidl bled ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn des Buach schlecht ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn des Buach fad ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn des Buach bled ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn de Gschicht schlecht ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn de Gschicht fad ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn de Gschicht bled ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn der Mo schlecht ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn der Mo fad ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn der Mo bled ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn d'Weid schlecht ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn d'Weid fad ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn d'Weid bled ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn d'Stod schlecht ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn d'Stod fad ist.
# Predicted: negative		Score: 0.07		Text: I mog des, wenn d'Stod bled ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn d'Zeid schlecht ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn d'Zeid fad ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn d'Zeid bled ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn s'Weda schlecht ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn s'Weda fad ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn s'Weda bled ist.
# Predicted: negative		Score: 0.03		Text: I mog des, wenn s'Lebm schlecht ist.
# Predicted: negative		Score: 0.04		Text: I mog des, wenn s'Lebm fad ist.
# Predicted: negative		Score: 0.05		Text: I mog des, wenn s'Lebm bled ist.

# %%
def visualise_cm(testsuite):
    # create figure with a subplot for each test
    test_names = list(testsuite.tests.keys())
    n_tests = len(test_names)

    # calculate rows and columns for the figure
    rows = int(np.sqrt(n_tests))
    cols = int(math.ceil(n_tests / rows))

    # create a figure for with rows x cols subplots
    _, axes = plt.subplots(rows, cols, figsize=(cols * 4, rows * 4))
    axes = axes.flatten() # for easy indexing

    # subplot(row, col, curr_plot)
    for idx, (test_name, test) in enumerate(testsuite.tests.items()):
        gold_labels = [idx2lbl[label] for label in test.labels] # convert to lexical labels for better readability
        pred_labels = [idx2lbl[label] for label in test.results["preds"]]
        
        # classes = list(lbl2idx.keys())
        classes = sorted(set(gold_labels + pred_labels)) # include all occuring labels

        cm = confusion_matrix(gold_labels, pred_labels)
        
        plt.subplot(rows, cols, idx+1)

        cm_disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
        cm_disp.plot(ax=axes[idx], cmap="Blues", colorbar=False)

        axes[idx].set_title(f"{test_name}")
    
    for i in range(len(testsuite.tests), len(axes)):
        axes[i].axis('off')

    plt.tight_layout(rect=[0, 0, 1.2, 0.95]) # bottom, left, right, and top spacing
    plt.suptitle(f"Confusion Matrices for {test_names[0][:3]}", x=0.64, fontsize=20)
    plt.show()

visualise_cm(eng_suite)
visualise_cm(deu_suite)
visualise_cm(bar_suite)
# Out:
# /home/miriam/Music/trustenv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
# German Sentiment Bert visualisation
visualise_cm(deu_suite_gerbert)
visualise_cm(bar_suite_gerbert)
# Out:
# /home/miriam/Music/trustenv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
